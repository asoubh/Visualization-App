# %%
import requests
import json
import pandas as pd

# %%
### Acquire national Covid data
# Ping national data API endpoint 
# Load response into JSON
# normialize JSON into dataframe
# clean data through sorting and NAN normialzation
# return df
def get_national_data():
    # API endpoint to query
    api_endpoint = 'https://api.covidtracking.com/v2/us/daily.json'
    
    # Make a GET request to the API
    api_response = requests.get(api_endpoint)

    # Check if the request was successful (status code 200)
    if api_response.status_code == 200:

        # try parsing and cleaning data
        try:
            # Parse the JSON data in the api_response
            json_data = api_response.json()

            # show top level keys from json response
            # print(json_data.keys())

            # Use pd.json_normalize to convert the JSON to a DataFrame
            normalized_data_df = pd.json_normalize(json_data['data'])

            # Data cleaning and sorting
                # sort by date
                # replace NAN entries with 0's
                # reset df inidicies
            normalized_data_df.sort_values(by='date', ascending=True, inplace=True)
            normalized_data_df=normalized_data_df.fillna(0)
            normalized_data_df.reset_index(inplace=True, drop=True)

            ### create list of level 1 parameters to load into listbox in toplevel script
            level_1_params=[]

            # for each column in the df (excluding the 'date' and 'states' column)
            for col in normalized_data_df.columns.values[2:]:
                
                # split column name on '.' and and first entry to list
                level_1_params.append(col.split('.')[0])

            # remove duplicates from list
            level_1_params = set(level_1_params)

            # return data that was fetched and cleaned
            return(normalized_data_df, level_1_params)
        
        # if there is an error in the parsing/cleaning process
        except:
            raise RuntimeError("Error while cleaning data.")

    # if request or data cleaning was not successful
    else:
        # Raise an error if the request was not successful
        raise RuntimeError(f"Error while fetching data from API.\n Error: {api_response.status_code}")

# %%
string1='ASDFJKL'

string1.lower()
# Out:
# 'asdfjkl'

# %%
### Acquire States Covid data
# Ping State data API endpoint 
# Load response into JSON
# normialize JSON into dataframe
# clean data through sorting and NAN normialzation
# return df
def get_state_data(state):
    # API endpoint to query
    # state name must be lower case for API endpoint
    api_endpoint = 'https://api.covidtracking.com/v2/states/' +(state.lower())+ '/daily.json'

    # Make a GET request to the API
    api_response = requests.get(api_endpoint)

    # Check if the request was successful (status code 200)
    if api_response.status_code == 200:

        # try parsing and cleaning data
        try:
            # Parse the JSON data in the api_response
            json_data = api_response.json()

            # show top level keys from json response
            # print(json_data.keys())

            # Use pd.json_normalize to convert the JSON to a DataFrame
            normalized_data_df = pd.json_normalize(json_data['data'])

            # Data cleaning and sorting
                # sort by date
                # replace NAN entries with 0's
                # reset df inidicies
            normalized_data_df.sort_values(by='date', ascending=True, inplace=True)
            normalized_data_df=normalized_data_df.fillna(0)
            normalized_data_df.reset_index(inplace=True, drop=True)

            ### create list of level 1 parameters to load into listbox in toplevel script
            level_1_params=[]

            # for each column in the df (excluding the 'date' and 'states' column)
            for col in normalized_data_df.columns.values[2:]:
                
                # split column name on '.' and and first entry to list
                level_1_params.append(col.split('.')[0])

            # remove duplicates from list
            level_1_params = set(level_1_params)

            # return data that was fetched and cleaned
            return(normalized_data_df, level_1_params)
        
        # if there is an error in the parsing/cleaning process
        except:
            raise RuntimeError("Error while cleaning data.")

    # if request or data cleaning was not successful
    else:
        # Raise an error if the request was not successful
        raise RuntimeError(f"Error while fetching data from API.\n Error: {api_response.status_code}")

# %%
state='WA'

# API endpoint to query
# state name must be lower case for API endpoint
api_endpoint = 'https://api.covidtracking.com/v2/us/daily.json'

# Make a GET request to the API
api_response = requests.get(api_endpoint)

# Check if the request was successful (status code 200)
if api_response.status_code == 200:

    # try parsing and cleaning data
    try:
        # Parse the JSON data in the api_response
        json_data = api_response.json()

        # show top level keys from json response
        # print(json_data.keys())

        # Use pd.json_normalize to convert the JSON to a DataFrame
        normalized_data_df = pd.json_normalize(json_data['data'])

        # Data cleaning and sorting
            # sort by date
            # replace NAN entries with 0's
            # reset df inidicies
        normalized_data_df.sort_values(by='date', ascending=True, inplace=True)
        normalized_data_df=normalized_data_df.fillna(0)
        normalized_data_df.reset_index(inplace=True, drop=True)

        ##### create list of level 1 parameters to load into listbox in toplevel script
        level_1_params=[]

        # for each column in the df (excluding the 'date' and 'states' column)
        for col in normalized_data_df.columns.values[2:]:
            
            # split column name on '.' and add first entry to list
            level_1_params.append(col.split('.')[0])

        # remove duplicates from list
        level_1_params = set(level_1_params)

        # filter metadata out
        level_1_params=[ent for ent in level_1_params if ent != 'meta']

        # return data that was fetched and cleaned
        # return(normalized_data_df, level_1_params)
    
    # if there is an error in the parsing/cleaning process
    except:
        raise RuntimeError("Error while cleaning data.")

# if request or data cleaning was not successful
else:
    # Raise an error if the request was not successful
    raise RuntimeError(f"Error while fetching data from API.\n Error: {api_response.status_code}")

# %%
normalized_data_df.columns.values
# Out:
# array(['date', 'states', 'cases.total.value',
#        'cases.total.calculated.population_percent',
#        'cases.total.calculated.change_from_prior_day',
#        'cases.total.calculated.seven_day_change_percent',
#        'testing.total.value',
#        'testing.total.calculated.population_percent',
#        'testing.total.calculated.change_from_prior_day',
#        'testing.total.calculated.seven_day_change_percent',
#        'outcomes.hospitalized.currently.value',
#        'outcomes.hospitalized.currently.calculated.population_percent',
#        'outcomes.hospitalized.currently.calculated.change_from_prior_day',
#        'outcomes.hospitalized.currently.calculated.seven_day_change_percent',
#        'outcomes.hospitalized.currently.calculated.seven_day_average',
#        'outcomes.hospitalized.in_icu.currently.value',
#        'outcomes.hospitalized.in_icu.currently.calculated.population_percent',
#        'outcomes.hospitalized.in_icu.currently.calculated.change_from_prior_day',
#        'outcomes.hospitalized.in_icu.currently.calculated.seven_day_change_percent',
#        'outcomes.hospitalized.in_icu.currently.calculated.seven_day_average',
#        'outcomes.hospitalized.on_ventilator.currently.value',
#        'outcomes.hospitalized.on_ventilator.currently.calculated.population_percent',
#        'outcomes.hospitalized.on_ventilator.currently.calculated.change_from_prior_day',
#        'outcomes.hospitalized.on_ventilator.currently.calculated.seven_day_change_percent',
#        'outcomes.hospitalized.on_ventilator.currently.calculated.seven_day_average',
#        'outcomes.death.total.value',
#        'outcomes.death.total.calculated.population_percent',
#        'outcomes.death.total.calculated.change_from_prior_day',
#        'outcomes.death.total.calculated.seven_day_change_percent',
#        'outcomes.death.total.calculated.seven_day_average'], dtype=object)

# %%
l1_param_selection='cases'
state_data_df=normalized_data_df

def get_L2_params(state_data_df, l1_param_selection):

    # use selection from first listbox (L1) to filter df columns on selection
    filtered_col_names=[col for col in list(state_data_df.columns.values[2:]) if col.split('.')[0] == l1_param_selection.lower()]

    ##### create list of level 2 parameters to load into listbox in toplevel script
    level_2_params=[]

    # for each column in the filtered list
    for col in filtered_col_names:
        
        # split column name on '.' and add second entry to list
        level_2_params.append(col.split('.')[1])

    # remove duplicates from list
    level_2_params = set(level_2_params)
    return(level_2_params)

# %%
normalized_data_df.columns.values
# Out:
# array(['date', 'states', 'cases.total.value',
#        'cases.total.calculated.population_percent',
#        'cases.total.calculated.change_from_prior_day',
#        'cases.total.calculated.seven_day_change_percent',
#        'testing.total.value',
#        'testing.total.calculated.population_percent',
#        'testing.total.calculated.change_from_prior_day',
#        'testing.total.calculated.seven_day_change_percent',
#        'outcomes.hospitalized.currently.value',
#        'outcomes.hospitalized.currently.calculated.population_percent',
#        'outcomes.hospitalized.currently.calculated.change_from_prior_day',
#        'outcomes.hospitalized.currently.calculated.seven_day_change_percent',
#        'outcomes.hospitalized.currently.calculated.seven_day_average',
#        'outcomes.hospitalized.in_icu.currently.value',
#        'outcomes.hospitalized.in_icu.currently.calculated.population_percent',
#        'outcomes.hospitalized.in_icu.currently.calculated.change_from_prior_day',
#        'outcomes.hospitalized.in_icu.currently.calculated.seven_day_change_percent',
#        'outcomes.hospitalized.in_icu.currently.calculated.seven_day_average',
#        'outcomes.hospitalized.on_ventilator.currently.value',
#        'outcomes.hospitalized.on_ventilator.currently.calculated.population_percent',
#        'outcomes.hospitalized.on_ventilator.currently.calculated.change_from_prior_day',
#        'outcomes.hospitalized.on_ventilator.currently.calculated.seven_day_change_percent',
#        'outcomes.hospitalized.on_ventilator.currently.calculated.seven_day_average',
#        'outcomes.death.total.value',
#        'outcomes.death.total.calculated.population_percent',
#        'outcomes.death.total.calculated.change_from_prior_day',
#        'outcomes.death.total.calculated.seven_day_change_percent',
#        'outcomes.death.total.calculated.seven_day_average'], dtype=object)

# %%
get_L2_params(state_data_df, l1_param_selection)
# Out:
# {'confirmed', 'probable', 'total'}

# %%
df, level_1_params = get_state_data('CA')
level_1_params
# Out:
# {'cases', 'meta', 'outcomes', 'tests'}

# %%
level_1_params=[]

# for each column in the df (excluding the 'date' and 'states' column)
for col in df.columns.values[2:]:
    
    # split column name on '.' and and first entry to list
    print(col.split('.')[1])
# Out:
# data_quality_grade
# updated
# tests
# total
# total
# total
# total
# confirmed
# confirmed
# confirmed
# confirmed
# confirmed
# probable
# probable
# probable
# probable
# probable
# pcr
# pcr
# pcr
# pcr
# pcr
# pcr
# pcr
# pcr
# pcr
# pcr
# pcr
# pcr
# pcr
# pcr
# pcr
# pcr
# pcr
# pcr
# pcr
# pcr
# pcr
# pcr
# pcr
# pcr
# pcr
# pcr
# pcr
# pcr
# pcr
# pcr
# pcr
# pcr
# pcr
# pcr
# pcr
# pcr
# pcr
# pcr
# pcr
# pcr
# antibody
# antibody
# antibody
# antibody
# antibody
# antibody
# antibody
# antibody
# antibody
# antibody
# antibody
# antibody
# antibody
# antibody
# antibody
# antibody
# antibody
# antibody
# antibody
# antibody
# antibody
# antibody
# antibody
# antibody
# antibody
# antibody
# antibody
# antibody
# antigen
# antigen
# antigen
# antigen
# antigen
# antigen
# antigen
# antigen
# antigen
# antigen
# antigen
# antigen
# antigen
# antigen
# antigen
# antigen
# antigen
# antigen
# antigen
# antigen
# antigen
# antigen
# antigen
# antigen
# antigen
# antigen
# antigen
# antigen
# recovered
# recovered
# recovered
# recovered
# recovered
# hospitalized
# hospitalized
# hospitalized
# hospitalized
# hospitalized
# hospitalized
# hospitalized
# hospitalized
# hospitalized
# hospitalized
# hospitalized
# hospitalized
# hospitalized
# hospitalized
# hospitalized
# hospitalized
# hospitalized
# hospitalized
# death
# death
# death
# death
# death
# death
# death
# death
# death
# death
# death
# death
# death
# death
# death
